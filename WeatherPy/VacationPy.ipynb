# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests


# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        Kelso  46.1468 -122.9084     38.62        90         100
# 1        1      Susuman  62.7833  148.1667    -29.02        98          82
# 2        2    Jamestown  42.0970  -79.2353     26.24        83         100
# 3        3     Waitangi -43.9535 -176.5597     65.82        93          64
# 4        4  Chibougamau  49.9168  -74.3659     -4.38        77         100
#
#    Wind Speed Country        Date
# 0        7.00      US  1705686081
# 1        1.01      RU  1705686081
# 2        6.91      US  1705685815
# 3        8.99      NZ  1705686082
# 4       11.50      CA  1705686082

# %%
#humidity = city_data_df["Humidity"].astype(int)
city_data_df["Humidity"]
# Out:
# 0      90
# 1      98
# 2      83
# 3      93
# 4      77
#        ..
# 591    40
# 592    78
# 593    25
# 594    54
# 595    78
# Name: Humidity, Length: 596, dtype: int64

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
humidity = city_data_df["Humidity"].astype(int)
# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75,
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %%
city_data_df
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0          0                Kelso  46.1468 -122.9084     38.62        90
# 1          1              Susuman  62.7833  148.1667    -29.02        98
# 2          2            Jamestown  42.0970  -79.2353     26.24        83
# 3          3             Waitangi -43.9535 -176.5597     65.82        93
# 4          4          Chibougamau  49.9168  -74.3659     -4.38        77
# ..       ...                  ...      ...       ...       ...       ...
# 591      591             Azangaro -14.9167  -70.2167     65.10        40
# 592      592               Bangor  54.6534   -5.6690     38.71        78
# 593      593  Ciudad Constitucion  25.0369 -111.6644     77.74        25
# 594      594          Tionk Essil  12.7856  -16.5217     86.05        54
# 595      595             Holualoa  19.6228 -155.9522     66.78        78
#
#      Cloudiness  Wind Speed Country        Date
# ...

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# converted to celisuis to farenheit
good_weather_df = city_data_df.loc[(city_data_df["Max Temp"] < 81) & (city_data_df["Max Temp"] > 70)]

#Wind speed less than 4.5 m/s
good_weather_df = good_weather_df.loc[(good_weather_df["Wind Speed"] < 7)]

#Zero cloudiness
good_weather_df = good_weather_df.loc[(good_weather_df["Cloudiness"] < 50)]

# Drop results with null values

good_weather_df = good_weather_df.dropna()

# Display sample data
print(good_weather_df.shape)
good_weather_df
# Out:
# (26, 10)
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 58        58            Port Augusta -32.5000  137.7667     77.18        24
# 60        60                  Avarua -21.2078 -159.7750     78.85        83
# 63        63                 Turabah  21.2141   41.6331     70.23        39
# 111      111  Hawaiian Paradise Park  19.5933 -154.9731     71.04        90
# 128      128                    Kone -21.0595  164.8658     77.47        91
# 137      137                Kalmunai   7.4167   81.8167     77.14        87
# 147      147         Plettenberg Bay -34.0527   23.3716     70.21        77
# 172      172                  La Foa -21.7108  165.8276     78.17        92
# 174      174              Port Blair  11.6667   92.7500     78.84        78
# 185      185              Srimushnam  11.4000   79.4167     73.90        85
# 196      196                    Hilo  19.7297 -155.0900     71.26        91
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
hotel_columns = ["City","Country","Lat","Lng","Humidity"]
hotel_df = good_weather_df.copy()[hotel_columns]
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 58             Port Augusta      AU -32.5000  137.7667        24
# 60                   Avarua      CK -21.2078 -159.7750        83
# 63                  Turabah      SA  21.2141   41.6331        39
# 111  Hawaiian Paradise Park      US  19.5933 -154.9731        90
# 128                    Kone      NC -21.0595  164.8658        91
# 137                Kalmunai      LK   7.4167   81.8167        87
# 147         Plettenberg Bay      ZA -34.0527   23.3716        77
# 172                  La Foa      NC -21.7108  165.8276        92
# 174              Port Blair      IN  11.6667   92.7500        78
# 185              Srimushnam      IN  11.4000   79.4167        85
# 196                    Hilo      US  19.7297 -155.0900        91
# 201             Kailua-Kona      US  19.6406 -155.9956        78
# 220               Laem Sing      TH  12.4816  102.0738        78
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Port Augusta - nearest hotel: Hotel Commonwealth
# Avarua - nearest hotel: Paradise Inn
# Turabah - nearest hotel: No hotel found
# Hawaiian Paradise Park - nearest hotel: No hotel found
# Kone - nearest hotel: Pacifik Appartels
# Kalmunai - nearest hotel: Saji new food
# Plettenberg Bay - nearest hotel: Milkwood Manor
# La Foa - nearest hotel: Oasis de Tendea
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Srimushnam - nearest hotel: No hotel found
# Hilo - nearest hotel: Dolphin Bay Hotel
# Kailua-Kona - nearest hotel: Kona Seaside Hotel
# Laem Sing - nearest hotel: The Pride Hotel
# Taoudenni - nearest hotel: No hotel found
# Wau - nearest hotel: Safari Park Hotel
# Srikakulam - nearest hotel: SVA Hotel Grand
# Phan Thiet - nearest hotel: Khách sạn Cà Ty
# Ouadda - nearest hotel: No hotel found
# Laranjeiras Do Sul - nearest hotel: Sandro Hotel
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Aswan - nearest hotel: Yaseen hotel
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75,
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
